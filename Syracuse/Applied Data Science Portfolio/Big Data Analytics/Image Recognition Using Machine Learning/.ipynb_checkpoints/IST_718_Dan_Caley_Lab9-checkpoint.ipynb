# %% [markdown]
# # Libraries

# %%
#!pip install -U -q keras-tuner

# %%
#!pip install keras

# %%
#!pip install sklearn

# %%
#!pip install tensorflow

# %%
# BASED ON scikit learn DOCUMENTATION

import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import check_random_state
from sklearn.model_selection import train_test_split

# Metrics for sklearn models
from sklearn.metrics import classification_report, confusion_matrix

# Timer
import timeit

# Plotting
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

# Import the SVM library from sklearn
from sklearn.svm import SVC

# Import the gridsearch library
from sklearn.model_selection import GridSearchCV

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.activations import relu, sigmoid
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.optimizers import Adam
from keras.callbacks import TensorBoard

# %% [markdown]
# # Obtain

# %%
# Bringing in the Fashion MNIST dataset
from keras.datasets import fashion_mnist

# %%
# Breaking the data into training and testing
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
# Looking at the Shape of the training data
# The second row is looking at how many associated labels for training
print(x_train.shape)
print(len(y_train))
# Out:
# (60000, 28, 28)
# 60000

# %%
# Looking at the Shape of the test data
# The second row is looking at how many associated labels for test
print(x_test.shape)
print(len(y_test))
# Out:
# (10000, 28, 28)
# 10000

# %%
# Splitting the data into training and test achieves an 83.3% Split
1 - len(y_test) / len(y_train)
# Out:
# 0.8333333333333334

# %%
# Plotting a figure
plt.figure()
plt.imshow(x_train[1], cmap='gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(12,12))
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(3,3,i+1)
	# plot raw pixel data
	plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
# show the figure
plt.show()

# %% [markdown]
# ## About the MNIST Data
#
# * Fashion MIST is a dataset from Zalano's aritcle image.  In total 70,000 images of a wide variaty of styles.
# * The training data consists of 60,000 images each at 28 x 28 pixels.
# * The training data consists of 10,000 images each at 28 x 28 pixels.
# * The data set has 10 different styles.
#   0. T-shirt/top
#   1. Trouser
#   2. Pullover
#   3. Dress
#   4. Coat
#   5. Sandal
#   6. Shirt
#   7. Sneaker
#   8. Bag
#   9. Ankle boot
#
# * Additional information about the data can be found here: https://github.com/zalandoresearch/fashion-mnist

# %% [markdown]
# # Scrubbing
#
# ## Normalizing the Data

# %%
# Creating Label names to apply to graphics
label_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Creating a plot for the first 9 images in the data set with their associated labels
plt.figure(figsize=(12,12))

# Looping through the first 9
for i in range(9):
  plt.subplot(3,3,i+1)
  
  # Removing the axis ticks
  plt.xticks([])
  plt.yticks([])

  # Removing gridlines
  plt.grid(False)

  # Showing the images
  plt.imshow(x_train[i], cmap=plt.cm.binary)

  # Adding associated label names
  plt.xlabel(label_names[y_train[i]])
    
plt.show()

# %%
# Converting the data to float 32
# Instead of our pixel data be 0 to 255 we want our data to be 1.
# so we will divide by 255

x_train = np.array(x_train, dtype=np.float32) / 255.0
y_train = np.array(y_train, dtype=np.float32) / 255.0

# %%
# Creating a validation datasete
x_train, x_validate, y_train, y_validate = train_test_split(
    x_train, y_train, test_size=0.2, random_state=5,
)

# %% [markdown]
# ## Shaping Data

# %%
# Reshaping the data some more
im_rows = 28
im_cols = 28
batch_size = 512
im_shape = (im_rows, im_cols, 1)

x_train = x_train.reshape(x_train.shape[0], *im_shape)
x_test = x_test.reshape(x_test.shape[0], *im_shape)
x_validate = x_validate.reshape(x_validate.shape[0], *im_shape)

print('x_train shape: {}'.format(x_train.shape))
print('x_test shape: {}'.format(x_test.shape))
print('x_validate shape: {}'.format(x_validate.shape))
# Out:
# x_train shape: (48000, 28, 28, 1)
# x_test shape: (10000, 28, 28, 1)
# x_validate shape: (12000, 28, 28, 1)

# %% [markdown]
# # Model

# %% [markdown]
# ## CNN Model
# * Define the Model
# * Create the Model
# * Fit the model

# %% [markdown]
# ### Define Model
# * Passing a kernal of 3 allows for an image to pass over each image to then identify the best fit.
# * Kernal's can be adjusted to identify better fit.
# * Here we will start with 3
# * MaxPooling allows you to downsample.
# * Shrinks the hieght and width down to 2.
# * Adding a dense layer creates a posterior probability.

# %%
cnn_model = Sequential([
                        Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=im_shape),
                        MaxPooling2D(pool_size=2),
                        Dropout(0.2),
                        Flatten(),
                        Dense(32, activation='relu'),
                        Dense(10, activation='softmax')
])
# Out:
# 2021-12-04 20:12:55.829651: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Creating Model

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard = TensorBoard(
    log_dir=log_dir.format('cnn_1layer'),
    write_graph = True,
    write_grads = True,
    histogram_freq = 1,
    write_images = True,
    
)


cnn_model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# 2021-12-04 20:23:10.481130: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2021-12-04 20:23:10.481146: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2021-12-04 20:23:10.481677: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.

# %%
# Out:
#   File "/var/folders/dw/jx8s08wn5t74fk513k4shfjr0000gn/T/ipykernel_24567/213534274.py", line 1
#     tensorboard --logdir logs/fit
#                          ^
# SyntaxError: invalid syntax

# %%
cnn_model.fit(
    x_train, y_train, batch_size=batch_size,
    epochs=10, verbose=1,
    validation_data=(x_validate, y_validate),
    callbacks=[tensorboard]
)
# Out:
# 2021-12-04 20:23:14.967803: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
#  2/94 [..............................] - ETA: 9s - loss: 2.0144 - accuracy: 0.0264
# 2021-12-04 20:23:27.865709: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2021-12-04 20:23:27.865727: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2021-12-04 20:23:27.962570: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2021-12-04 20:23:27.964653: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2021-12-04 20:23:27.973383: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27
# 2021-12-04 20:23:27.978032: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27/Daniels-MacBook-Pro.local.trace.json.gz
# 2021-12-04 20:23:27.984214: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27
# 2021-12-04 20:23:27.984466: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27/Daniels-MacBook-Pro.local.memory_profile.json.gz
# 2021-12-04 20:23:27.985490: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27Dumped tool data for xplane.pb to logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27/Daniels-MacBook-Pro.local.xplane.pb
# Dumped tool data for overview_page.pb to logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27/Daniels-MacBook-Pro.local.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27/Daniels-MacBook-Pro.local.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27/Daniels-MacBook-Pro.local.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs\cnn_1layer/train/plugins/profile/2021_12_04_20_23_27/Daniels-MacBook-Pro.local.kernel_stats.pb
# 94/94 [==============================] - 22s 103ms/step - loss: 0.2205 - accuracy: 0.0965 - val_loss: 1.0662e-05 - val_accuracy: 0.1002
# Epoch 2/10
# 94/94 [==============================] - 9s 95ms/step - loss: 1.1279e-05 - accuracy: 0.1013 - val_loss: 9.6589e-06 - val_accuracy: 0.1002
# Epoch 3/10
# 94/94 [==============================] - 9s 95ms/step - loss: 9.8757e-06 - accuracy: 0.1028 - val_loss: 8.4729e-06 - val_accuracy: 0.1002
# Epoch 4/10
# 94/94 [==============================] - 9s 95ms/step - loss: 7.8928e-06 - accuracy: 0.1004 - val_loss: 7.2162e-06 - val_accuracy: 0.1002
# Epoch 5/10
# 94/94 [==============================] - 9s 95ms/step - loss: 7.0222e-06 - accuracy: 0.1009 - val_loss: 5.8032e-06 - val_accuracy: 0.1002
# Epoch 6/10
# 94/94 [==============================] - 9s 95ms/step - loss: 6.2329e-06 - accuracy: 0.0998 - val_loss: 4.5641e-06 - val_accuracy: 0.1002
# Epoch 7/10
# 94/94 [==============================] - 9s 96ms/step - loss: 4.6065e-06 - accuracy: 0.0989 - val_loss: 3.5523e-06 - val_accuracy: 0.1002
# Epoch 8/10
# 94/94 [==============================] - 9s 97ms/step - loss: 3.0586e-06 - accuracy: 0.0996 - val_loss: 2.7880e-06 - val_accuracy: 0.1002
# Epoch 9/10
# 94/94 [==============================] - 9s 98ms/step - loss: 2.6107e-06 - accuracy: 0.1005 - val_loss: 2.2079e-06 - val_accuracy: 0.1002
# Epoch 10/10
# 94/94 [==============================] - 9s 99ms/step - loss: 1.9475e-06 - accuracy: 0.1000 - val_loss: 1.7876e-06 - val_accuracy: 0.1002

# %% [markdown]
# ## Fitting the Model

# %%
score = cnn_model.evaluate(x_test, y_test, verbose=0)

print('test loss: {:.4f}'.format(score[0]))
print(' test acc: {:.4f}'.format(score[1]))
# Out:
# test loss: 6889.6704
#  test acc: 0.1000
